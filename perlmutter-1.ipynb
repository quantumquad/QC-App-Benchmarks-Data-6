# %% [raw]
# ### QED-C Application-Oriented Benchmarks - Execution on Perlmutter - Paper Images

# %%
# Reference the __common files from main repo (maxcut branch for now)

# Change this to location of your QED-C code repo
repo = "../QC-App-Oriented-Benchmarks-develop"

import sys
sys.path.insert(1, repo)

from _common import metrics

# %% [markdown]
# ### NERSC Perlmutter - QFT (1)

# %%
backend_id='nvidia-8g-250716-34q'

metrics.plot_metrics_for_app(backend_id, "Quantum Fourier Transform (1)", filters=["execute", "depth"], suffix="-ed")
