# %% [markdown]
# ### QED-C Application-Oriented Benchmarks - Dynamic Circuits - Paper Images

# %%
# Reference the __common files from main repo (maxcut branch for now)

# Change this to location of your QED-C code repo
repo = "../QC-App-Oriented-Benchmarks-develop"

import sys
sys.path.insert(1, repo)

from _common import metrics

# %% [markdown]
# ### IBM Sherbrooke - QFT (1)

# %%
backend_id='ibm_sherbrooke-250628'

metrics.plot_metrics_for_app(backend_id, "Quantum Fourier Transform (1)", filters=["fidelity", "execute", "depth"], suffix="-fed")

# %% [markdown]
# ### IBM Sherbrooke - QFT (2)

# %%
backend_id='ibm_sherbrooke-250628'

metrics.plot_metrics_for_app(backend_id, "Quantum Fourier Transform (2)", filters=["fidelity", "execute", "depth"], suffix="-fed")

# %% [markdown]
# ### IBM Sherbrooke - QPE

# %%
backend_id='ibm_sherbrooke-250628'

metrics.plot_metrics_for_app(backend_id, "Phase Estimation", filters=["fidelity", "execute", "depth"], suffix="-fed")

# %% [markdown]
# ### IBM Sherbrooke - QFT (2)  - Dynamic

# %%
backend_id='ibm_sherbrooke-250628-mcm'

metrics.plot_metrics_for_app(backend_id, "Quantum Fourier Transform (2)", filters=["fidelity", "execute", "depth"], suffix="-fed")

# %% [markdown]
# ### IBM Sherbrooke - QPE - Dynamic

# %%
backend_id='ibm_sherbrooke-250628-mcm'

metrics.plot_metrics_for_app(backend_id, "Phase Estimation", filters=["fidelity", "execute", "depth"], suffix="-fed")

# %% [markdown]
# ### IBM Sherbrooke - QFT (2) - Extra run of this one

# %%
backend_id='ibm_sherbrooke-250628-2'

metrics.plot_metrics_for_app(backend_id, "Quantum Fourier Transform (2)", filters=["fidelity", "execute", "depth"], suffix="-fed")
